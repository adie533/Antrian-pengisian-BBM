# %%
from collections import deque 


priority_bbm = {
    "Pertamax Turbo": 1,
    "Pertamax": 2,
    "Pertalite": 3
}


def add_kendaraan(antrian, jenis, plat, bbm):
    indeks_sisip = len(antrian)
    for i, (_, _, bbm_kendaraan) in enumerate(antrian):
        if priority_bbm[bbm_kendaraan] > priority_bbm[bbm]:
            indeks_sisip = i
            break
    antrian.insert(indeks_sisip, (jenis, plat, bbm))
    print(f'{jenis} dengan plat {plat} masuk antrian.')


def show_queue(antrian):
    if antrian:
        print("\nPengisian BBM prioritas: ")
        for i, (jenis, plat, bbm) in enumerate(antrian, 1):
            print(f'{i}. {jenis} - {plat} - {bbm}')
    else:
        print("Tidak ada antrian.")

antrian_bbm = deque()



while True:
    print("\nMenu:")
    print("1. Tambah Kendaraan")
    print("2. Antrian/Keluar")

    pilihan = input("Pilih menu: ")
    if pilihan == "1":
        print("\nPilih Jenis Kendaraan:")
        print("1. Motor")
        print("2. Mobil")
        kendaraan_input = input("Pilih jenis kendaraan: ")
        if kendaraan_input == "1":
            jenis_kendaraan = "Motor"
        elif kendaraan_input == "2":
            jenis_kendaraan = "Mobil"
        else:
            print("Pilihan tidak valid.")
            continue

        print ("\nPlat kendaraan: ")
        plat_nomor = input("Masukkan nomor plat kendaraan: ")
        print(f'plat nomor : {plat_nomor}')

        print("\nPilih Jenis BBM:")
        print("1. Pertamax Turbo")
        print("2. Pertamax")
        print("3. Pertalite")
        bbm_input = input("Pilih jenis BBM: ")
        if bbm_input == "1":
            jenis_bbm = "Pertamax Turbo"
        elif bbm_input == "2":
            jenis_bbm = "Pertamax"
        elif bbm_input == "3":
            jenis_bbm = "Pertalite"
        else:
            print("Pilihan tidak valid.")
            continue

        add_kendaraan(antrian_bbm, jenis_kendaraan, plat_nomor, jenis_bbm)
    elif pilihan == "2":
        show_queue(antrian_bbm)
        break
    else:
        print("Pilihan tidak valid.")
# Out:
# Menu:
# 1. Tambah Kendaraan
# 2. Antrian/Keluar
#
# Pilih Jenis Kendaraan:
# 1. Motor
# 2. Mobil
#
# Plat kendaraan:
# plat nomor : BM 1 RI
#
# Pilih Jenis BBM:
# 1. Pertamax Turbo
# 2. Pertamax
# 3. Pertalite
# Mobil dengan plat BM 1 RI masuk antrian.
#
# Menu:
# 1. Tambah Kendaraan
# 2. Antrian/Keluar
#
# Pilih Jenis Kendaraan:
# 1. Motor
# 2. Mobil
#
# Plat kendaraan:
# plat nomor : BM 2 RI
#
# Pilih Jenis BBM:
# 1. Pertamax Turbo
# 2. Pertamax
# 3. Pertalite
# Motor dengan plat BM 2 RI masuk antrian.
#
# Menu:
# 1. Tambah Kendaraan
# 2. Antrian/Keluar
#
# Pilih Jenis Kendaraan:
# 1. Motor
# 2. Mobil
#
# Plat kendaraan:
# plat nomor : BM 3 RI
#
# Pilih Jenis BBM:
# 1. Pertamax Turbo
# 2. Pertamax
# 3. Pertalite
# Mobil dengan plat BM 3 RI  masuk antrian.
#
# Menu:
# 1. Tambah Kendaraan
# 2. Antrian/Keluar
#
# Pilih Jenis Kendaraan:
# 1. Motor
# 2. Mobil
#
# Plat kendaraan:
# plat nomor : BM 4 RI
#
# Pilih Jenis BBM:
# 1. Pertamax Turbo
# 2. Pertamax
# 3. Pertalite
# Motor dengan plat BM 4 RI masuk antrian.
#
# Menu:
# 1. Tambah Kendaraan
# 2. Antrian/Keluar
#
# Pengisian BBM prioritas:
# 1. Motor - BM 2 RI - Pertamax Turbo
# 2. Motor - BM 4 RI - Pertamax Turbo
# 3. Mobil - BM 1 RI - Pertamax
# 4. Mobil - BM 3 RI  - Pertalite
